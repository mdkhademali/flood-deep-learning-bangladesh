# %% [markdown]
# # 01: Data Exploration
# Loads exported Sentinel-1 composites and reference flood labels, and inspects basic statistics and backscatter distributions.
#
# Run `gee/sentinel1_preprocessing.js` and `gee/flood_dataset_export.js` first and place the outputs in `data/raw/`.

# %%
import sys
sys.path.insert(0, '..')
import numpy as np
import rasterio
import matplotlib.pyplot as plt
from src.utils.common import load_config

cfg = load_config('../configs/config.yaml')
cfg['study_area']

# %% [markdown]
# ## Load a Sentinel-1 composite
# Update the path once real exports are available in `data/raw/`.

# %%
image_path = '../data/raw/Kurigram_S1_peakflood_2020.tif'  # update once exported
# with rasterio.open(image_path) as src:
#     arr = src.read()
#     profile = src.profile
# print(arr.shape, profile)

# %% [markdown]
# ## Backscatter distribution (VV vs VH)
# Once data is loaded above, inspect the histogram of VV/VH values to sanity check the dB range and speckle level.

# %%
# fig, axes = plt.subplots(1, 2, figsize=(10, 4))
# axes[0].hist(arr[0].ravel(), bins=100); axes[0].set_title('VV (dB)')
# axes[1].hist(arr[1].ravel(), bins=100); axes[1].set_title('VH (dB)')
# plt.show()
