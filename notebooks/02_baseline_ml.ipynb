# %% [markdown]
# # 02: Baseline Machine Learning (Random Forest / XGBoost)
# This notebook is a thin wrapper around `src/training/train_baseline.py`. All logic lives in `src/` for testability — see Section 6 of the project brief (modular scripts over one huge notebook).

# %%
import sys
sys.path.insert(0, '..')
from src.training.train_baseline import main as train_baseline_main

# Update paths once real Sentinel-1 exports are available
# results = train_baseline_main(
#     config_path='../configs/config.yaml',
#     pre_vv='../data/raw/preflood_VV.tif', pre_vh='../data/raw/preflood_VH.tif',
#     peak_vv='../data/raw/peakflood_VV.tif', peak_vh='../data/raw/peakflood_VH.tif',
#     label_path='../data/raw/Kurigram_flood_label_2020.tif',
# )
# results

# %% [markdown]
# ## Feature importance (Figure 6)

# %%
from src.evaluation.make_figures import fig06_feature_importance
# fig06_feature_importance('../outputs/metrics/rf_feature_importance.json')
