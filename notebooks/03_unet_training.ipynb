# %% [markdown]
# # 03: U-Net Training
# Thin wrapper around `src/training/train_unet.py`. Use `--debug` first to verify the pipeline runs end-to-end on a small subset before committing to a full training run.

# %%
import sys
sys.path.insert(0, '..')
from src.training.train_unet import train

# Fast smoke test
# history = train(config_path='../configs/config.yaml', debug=True,
#                  image_path='../data/raw/Kurigram_S1_peakflood_2020.tif',
#                  label_path='../data/raw/Kurigram_flood_label_2020.tif')

# %% [markdown]
# ## Full training run

# %%
# history = train(config_path='../configs/config.yaml', debug=False,
#                  image_path='../data/raw/Kurigram_S1_peakflood_2020.tif',
#                  label_path='../data/raw/Kurigram_flood_label_2020.tif',
#                  experiment='B_vv_vh')

# %% [markdown]
# ## Training curves (Figures 7-8)

# %%
from src.evaluation.make_figures import fig07_08_training_curves
# fig07_08_training_curves('../outputs/metrics/unet_training_history.json')
