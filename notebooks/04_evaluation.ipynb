# %% [markdown]
# # 04: Evaluation & Multi-Temporal Flood Mapping
# Applies the trained U-Net to full scenes, computes accuracy metrics, multi-temporal flood dynamics, and exposure analysis, and generates the remaining publication figures.

# %%
import sys
sys.path.insert(0, '..')
from src.mapping.flood_mapping import map_flood_extent, flood_dynamics
from src.evaluation.metrics import compute_binary_metrics, format_metrics_table
from src.evaluation.make_figures import (
    fig09_confusion_matrix, fig11_flood_extent_map,
    fig12_multitemporal_dynamics, fig13_flooded_area_timeseries,
)

# %% [markdown]
# ## Apply model to pre/peak/post composites

# %%
# pre_map, _ = map_flood_extent('../data/raw/Kurigram_S1_preflood_2020.tif',
#                                '../outputs/models/unet_best.pt',
#                                '../outputs/maps/preflood_2020.tif')
# peak_map, _ = map_flood_extent('../data/raw/Kurigram_S1_peakflood_2020.tif',
#                                 '../outputs/models/unet_best.pt',
#                                 '../outputs/maps/peakflood_2020.tif')
# post_map, _ = map_flood_extent('../data/raw/Kurigram_S1_postflood_2020.tif',
#                                 '../outputs/models/unet_best.pt',
#                                 '../outputs/maps/postflood_2020.tif')

# %% [markdown]
# ## Multi-temporal flood dynamics (Figures 12-13)

# %%
# dynamics = flood_dynamics(pre_map, peak_map, post_map)
# dynamics

# %% [markdown]
# ## Exposure analysis (Figures 14-15)
# See `src/mapping/exposure_analysis.py`, requires LULC and admin boundary vector layers.
